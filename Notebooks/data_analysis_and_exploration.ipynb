# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Data exploration and analysis

# %% [markdown]
# After learning some of the basics of scientific computing with python, we should now be ready to tackle some real data. In the following example, we will learn how to read data from file, how to build a rudimentary analysis of the data and how to modularize it into functions. We will talk briefly about profiling functions, before moving on. In the following segment, we will look at organizing these components into a reproducible workflow.
#
# **Note** : This is a typical workflow. Learn the parameters of your problem in an interactive environment and then scale it up in a non-interactive mode

# %% [markdown]
# First, a couple of words about the data we will use. For the examples we will look at here, we will look at data taken from electrophysiological experiments conducted on the grasshopper `Locusta Migratoria`. These grasshoppers use acoustic communication as part of their courtship process. This means that hearing is an exremely important sense for them. The grasshoppers hear through ears located near the base of their hind-legs. A tympanal membrane transforms acoustic air-vibrations into mechanical stimuli, which are transduced into electrical signals in the cell bodies of approximately 70 auditory receptor cells located in the ears on each side.
#
# These receptor cells generate action potentials, which travel down the axons of these cells to a sensory ganglion located in the meta-thoracic segment of the grasshopper body. The information is further processed there and affects the behavior of the animal.
#
# In the following example, we will look at intra-cellular data recorded using sharp electrodes from the axons of these auditory receptor cells. The data was stored as the times relative to the beginning of the experiment at which a spike was detected in the voltage trace of the recording. In addition, we also have the stimulus that was presented, stored as voltage values that were sent to the speakers. Using these two bits of information we will calculate the spike-triggered average stimulus (or STA). This is often used as a way to characterize the filter properties of the cell.
#
# The full data set is available do download on the [CRCNS website](crcns.org). More details about this data can be found in [this paper](http://arokem.org/publications/papers/Rokem2006InfoJiitter.pdf).

# %% [markdown]
# # Getting the data.
#
# Let's start by getting the data. I have placed a zip file with the data we will need in this link: http://arokem.org/data/grasshoppers.zip
#
# Let's copy the data to the same location as this notebook

# %%
pylab inline
# Out:
#   File "<ipython-input-2-b794e5809f34>", line 1
#     pylab inline
#                ^
# SyntaxError: invalid syntax

# %%
cd ../grasshoppers/
# Out:
# /Users/jadz/Documents/Scripts/Python/grasshoppers

# %%
# !pwd
# !ls
# Out:
# /Users/jadz/Documents/Scripts/Python/grasshoppers
# grasshopper_spike_times1.txt grasshopper_stimulus1.txt
# grasshopper_spike_times2.txt grasshopper_stimulus2.txt

# %% [markdown]
# In addition to the notebooks and `.md` files in this directory, you should now also see these files:
#
#     grasshopper_spike_times1.txt
#     grasshopper_spike_times2.txt
#     grasshopper_stimulus1.txt
#     grasshopper_stimulus2.txt
#
# There are several different types of data-files you might encounter:
#
# - Text files (such as these) are easy to read using one of the following:
#
#         file
#
#         np.loadtxt
#
# - A special case of text files are csv files. These can be read using the above methods or using
#
#         mlab.csv2rec
#
#   We'll demonstrate that in just a bit
#
# - Binary file formats. These kinds of files are useful, because they can be used to store large amounts of data in a structured manner. But these include a variety of specialized formats. To read these, you will often require some knowledge about the structure and contents of the file. In particular, neuroimaging data is a binary file format that can be a headache to deal with. Fortunately, the excellent `nibabel` library knows how to deal with many of these files. To deal with dicom files (yet another bff...), you can use `pydicom`
#
# - Files from Matlab. Since many of you use matlab, you might encounter mat-files on a regular basis. I will just mention that there are several options for handling those files. For some mat files, you can use the `scipy.io` module, which contains `loadmat' and `savemat` functions. Another option is the more complicated PyTables library, which supports the HDF5 file format (which is used in some versions of Matlab).
#
#
# Let's start by looking at the most generic form of file i/o:

# %% [markdown]
# ## Using `file` objects
#
# We start by using the python [`file` class](http://docs.python.org/2/tutorial/inputoutput.html#reading-and-writing-files). Calling the built-in `open` returns a `file` class instance (object). The first input to this function is a string containing the path to the file (relative or absolute). The second input is the mode in which the file is opened: `'r'` designates 'read', `'w'` designates 'write' and `'a'` designates 'append'. In this case, we only want to read the file (not change it!):

# %%
# We open a file, and get back a file object:
f_st_1 = open('grasshopper_spike_times1.txt', 'r')

# %% [markdown]
# Take a look at the object you got and its methods.
#
#
# One method that seems useful is the `read` method. Let's call it

# %%
# Use the read method:
r = f_st_1.read()

# %% [markdown]
# What did we get back?

# %%
# To examine what something is, you can use `type`
type(r)
# Out:
# str

# %% [markdown]
# Let's take a look:

# %%
# Look at it's representation
r
# Out:
# '# repro call number: 0\n# mode: 3\n# signal: 1\n# stimulus file: /extra/setup/oel/stimuli/receptorInfo/gauss_st6_co200.dat\n# carrier freq (kHz): 2.5\n# stimulus length (msec): 1000\n# pause between stimuli (msec): 700\n# length of ramp (usec): 1000\n# desired firing rate (Hz): 100\n# standard deviation (dB): 6\n# cut-off frequency (Hz): 200\n# repetition number: 0\n# duration (msec): 1000\n# intensity (dB): 76.4286\n6700\n9900\n13900\n20100\n25000\n28400\n37000\n40600\n46300\n50500\n59900\n68800\n75200\n80600\n84300\n88000\n93200\n104800\n118400\n128500\n135800\n145600\n148800\n157100\n170900\n182800\n198600\n209500\n214000\n217900\n221100\n228700\n238500\n244500\n257600\n261800\n269100\n278200\n285400\n299100\n302800\n306100\n333900\n343800\n352300\n355900\n362200\n368300\n371700\n386900\n397400\n404600\n413300\n418900\n427400\n430800\n435900\n441400\n456100\n461600\n465200\n469300\n474400\n480700\n484600\n488700\n496800\n503800\n514500\n530100\n536700\n544800\n549400\n554600\n564000\n584300\n591200\n597500\n607500\n611800\n615500\n619100\n627200\n631500\n635200\n658900\n669700\n674300\n678300\n683300\n690000\n693700\n704900\n716000\n719700\n724600\n729800\n740800\n749300\n759500\n770900\n790800\n794400\n801600\n813100\n817100\n835000\n845000\n849900\n857700\n865200\n868900\n875000\n883900\n893600\n904600\n919100\n924900\n929900\n936400\n940200\n957700\n961700\n967900\n973300\n979400\n988200\n1002800\n1009400\n1024000\n1030100\n1047600\n1056200\n1067200\n1076400\n1081100\n1087900\n1096200\n1114300\n1126000\n1135300\n1143100\n1152600\n1157500\n1166000\n1175900\n1185900\n1191800\n1199400\n1212000\n1223700\n1235100\n1240600\n1245300\n1251600\n1256600\n1267500\n1274200\n1286600\n1291300\n1296500\n1305600\n1312500\n1316900\n1338500\n1345200\n1364100\n1378500\n1390700\n1394700\n1400300\n1405600\n1412500\n1420200\n1430600\n1447000\n1451900\n1478200\n1488100\n1499900\n1511900\n1517400\n1532000\n1542800\n1550000\n1555700\n1580600\n1587700\n1593600\n1609400\n1616800\n1627700\n1635000\n1639900\n1656700\n1661900\n1671700\n1678900\n1683600\n1692900\n1705500\n1721600\n1727800\n1736600\n1743300\n1756700\n1761200\n1780700\n1787100\n1810000\n1815800\n1827200\n1833900\n1841400\n1856200\n1862800\n1868200\n1877700\n1890800\n1899600\n1912700\n1932100\n1950400\n1961100\n1967700\n1972200\n1988400\n1997800\n2002400\n2016800\n2034400\n2048300\n2056900\n2069800\n2078800\n2084200\n2099600\n2110500\n2115600\n2135400\n2162100\n2171300\n2181400\n2192900\n2209600\n2215700\n2230400\n2237600\n2243700\n2257000\n2261800\n2267200\n2273600\n2278600\n2290700\n2296400\n2303100\n2315400\n2320300\n2328000\n2341900\n2347500\n2357300\n2371900\n2377400\n2383200\n2393800\n2398800\n2413100\n2427300\n2434700\n2442100\n2453900\n2460100\n2477900\n2493200\n2498400\n2511900\n2519100\n2527500\n2544900\n2563700\n2573200\n2579800\n2589100\n2594400\n2600400\n2609400\n2614500\n2625900\n2639400\n2650000\n2660600\n2674800\n2690800\n2698100\n2702900\n2715100\n2725800\n2739900\n2751200\n2757300\n2769000\n2776300\n2790900\n2797600\n2809500\n2816400\n2823700\n2833100\n2838600\n2843500\n2849800\n2860400\n2866700\n2879200\n2887500\n2893000\n2897700\n2904900\n2915000\n2925800\n2931800\n2938600\n2948000\n2957400\n2964000\n2969600\n2983500\n2992800\n2999300\n3014800\n3026700\n3039700\n3045900\n3056400\n3064500\n3074700\n3090600\n3102500\n3113300\n3122500\n3135500\n3145700\n3155100\n3164300\n3188400\n3196300\n3201200\n3213300\n3229800\n3235700\n3247800\n3254800\n3261900\n3272000\n3279500\n3287000\n3297100\n3304900\n3322200\n3339600\n3350700\n3357600\n3368700\n3376300\n3385200\n3391800\n3398800\n3421000\n3431800\n3450300\n3456300\n3470800\n3476800\n3482200\n3494100\n3507200\n3517000\n3538200\n3546100\n3554300\n3571600\n3579700\n3588700\n3597100\n3610600\n3621200\n3638800\n3644100\n3650600\n3661500\n3673000\n3683700\n3713600\n3724900\n3745900\n3750800\n3756200\n3763000\n3768500\n3783500\n3795000\n3803600\n3808900\n3820100\n3836100\n3844900\n3856000\n3872400\n3878600\n3887700\n3900500\n3906400 ...

# %% [markdown]
# What if we ask python to `print` it?

# %%
# Printing isn't always the same as representing it:
print(r)
# Out:
# # repro call number: 0
# # mode: 3
# # signal: 1
# # stimulus file: /extra/setup/oel/stimuli/receptorInfo/gauss_st6_co200.dat
# # carrier freq (kHz): 2.5
# # stimulus length (msec): 1000
# # pause between stimuli (msec): 700
# # length of ramp (usec): 1000
# # desired firing rate (Hz): 100
# # standard deviation (dB): 6
# # cut-off frequency (Hz): 200
# # repetition number: 0
# # duration (msec): 1000
# # intensity (dB): 76.4286
# 6700
# 9900
# 13900
# 20100
# 25000
# 28400
# 37000
# 40600
# 46300
# 50500
# 59900
# 68800
# 75200
# 80600
# 84300
# 88000
# 93200
# 104800
# 118400
# 128500
# 135800
# 145600
# 148800
# 157100
# 170900
# 182800
# 198600
# 209500
# 214000
# 217900
# 221100
# 228700
# 238500
# 244500
# 257600
# 261800
# 269100
# 278200
# 285400
# 299100
# 302800
# 306100
# 333900
# 343800
# 352300
# 355900
# 362200
# 368300
# 371700
# 386900
# 397400
# 404600
# 413300
# 418900
# 427400
# 430800
# 435900
# 441400
# 456100
# 461600
# 465200
# 469300
# 474400
# 480700
# 484600
# 488700
# 496800
# 503800
# 514500
# 530100
# 536700
# 544800
# 549400
# 554600
# 564000
# 584300
# 591200
# 597500
# 607500
# 611800
# 615500
# 619100
# 627200
# 631500
# 635200
# 658900
# 669700
# 674300
# 678300
# 683300
# 690000
# 693700
# 704900
# 716000
# 719700
# 724600
# 729800
# 740800
# 749300
# 759500
# 770900
# 790800
# 794400
# 801600
# 813100
# 817100
# 835000
# 845000
# 849900
# 857700
# 865200
# 868900
# 875000
# 883900
# 893600
# 904600
# 919100
# 924900
# 929900
# 936400
# 940200
# 957700
# 961700
# 967900
# 973300
# 979400
# 988200
# 1002800
# 1009400
# 1024000
# 1030100
# 1047600
# 1056200
# 1067200
# 1076400
# 1081100
# 1087900
# 1096200
# 1114300
# 1126000
# 1135300
# 1143100
# 1152600
# 1157500
# 1166000
# 1175900
# 1185900
# 1191800
# 1199400
# 1212000
# 1223700
# 1235100
# 1240600
# 1245300
# 1251600
# 1256600
# 1267500
# 1274200
# 1286600
# 1291300
# 1296500
# 1305600
# 1312500
# 1316900
# 1338500
# 1345200
# 1364100
# 1378500
# 1390700
# 1394700
# 1400300
# 1405600
# 1412500
# 1420200
# 1430600
# 1447000
# 1451900
# 1478200
# 1488100
# 1499900
# 1511900
# 1517400
# 1532000
# 1542800
# 1550000
# 1555700
# 1580600
# 1587700
# 1593600
# 1609400
# 1616800
# 1627700
# 1635000
# 1639900
# 1656700
# 1661900
# 1671700
# 1678900
# 1683600
# 1692900
# 1705500
# 1721600
# 1727800
# 1736600
# 1743300
# 1756700
# 1761200
# 1780700
# 1787100
# 1810000
# 1815800
# 1827200
# 1833900
# 1841400
# 1856200
# 1862800
# 1868200
# 1877700
# 1890800
# 1899600
# 1912700
# 1932100
# 1950400
# 1961100
# 1967700
# 1972200
# 1988400
# 1997800
# 2002400
# 2016800
# 2034400
# 2048300
# 2056900
# 2069800
# 2078800
# 2084200
# 2099600
# 2110500
# 2115600
# 2135400
# 2162100
# 2171300
# 2181400
# 2192900
# 2209600
# 2215700
# 2230400
# 2237600
# 2243700
# 2257000
# 2261800
# 2267200
# 2273600
# 2278600
# 2290700
# 2296400
# 2303100
# 2315400
# 2320300
# 2328000
# 2341900
# 2347500
# 2357300
# 2371900
# 2377400
# 2383200
# 2393800
# 2398800
# 2413100
# 2427300
# 2434700
# 2442100
# 2453900
# 2460100
# 2477900
# 2493200
# 2498400
# 2511900
# 2519100
# 2527500
# 2544900
# 2563700
# 2573200
# 2579800
# 2589100
# 2594400
# 2600400
# 2609400
# 2614500
# 2625900
# 2639400
# 2650000
# 2660600
# 2674800
# 2690800
# 2698100
# 2702900
# 2715100
# 2725800
# 2739900
# 2751200
# 2757300
# 2769000
# 2776300
# 2790900
# 2797600
# 2809500
# 2816400
# 2823700
# 2833100
# 2838600
# 2843500
# 2849800
# 2860400
# 2866700
# 2879200
# 2887500
# 2893000
# 2897700
# 2904900
# 2915000
# 2925800
# 2931800
# 2938600
# 2948000
# 2957400
# 2964000
# 2969600
# 2983500
# 2992800
# 2999300
# 3014800
# 3026700
# 3039700
# 3045900
# 3056400
# 3064500
# 3074700
# 3090600
# 3102500
# 3113300
# 3122500
# 3135500
# 3145700
# 3155100
# 3164300
# 3188400
# 3196300
# 3201200
# 3213300
# 3229800
# 3235700
# 3247800
# 3254800
# 3261900
# 3272000
# 3279500
# 3287000
# 3297100
# 3304900
# 3322200
# 3339600
# 3350700
# 3357600
# 3368700
# 3376300
# 3385200
# 3391800
# 3398800
# 3421000
# 3431800
# 3450300
# 3456300
# 3470800
# 3476800
# 3482200
# 3494100
# 3507200
# 3517000
# 3538200
# 3546100
# 3554300
# 3571600
# 3579700
# 3588700
# 3597100
# 3610600
# 3621200
# 3638800
# 3644100
# 3650600
# 3661500
# 3673000
# 3683700
# 3713600
# 3724900
# 3745900
# 3750800
# 3756200
# 3763000
# 3768500
# 3783500
# 3795000
# 3803600
# 3808900
# 3820100
# 3836100
# 3844900
# 3856000
# 3872400
# 3878600
# 3887700
# 3900500
# 3906400
# 3917200
# 3922400
# 3932200
# 3947200
# 3956500
# 3974400
# 3993100
# 4002200
# 4007000
# 4012600
# 4019500
# 4044300
# 4052700
# 4064700
# 4073300
# 4084900
# 4098300
# 4104900
# 4117600
# 4122700
# 4132600
# 4162400
# 4172100
# 4177100
# 4186700
# 4192000
# 4199000
# 4204300
# 4218200
# 4225200
# 4234600
# 4240400
# 4247300
# 4263900
# 4282100
# 4289800
# 4298300
# 4315300
# 4324300
# 4332900
# 4349300
# 4369300
# 4377900
# 4393600
# 4401700
# 4407700
# 4426400
# 4432100
# 4440500
# 4447300
# 4454600
# 4469900
# 4476900
# 4485600
# 4491500
# 4498700
# 4508000
# 4524500
# 4535900
# 4558300
# 4565100
# 4575900
# 4587100
# 4593400
# 4600800
# 4611800
# 4640300
# 4651600
# 4663600
# 4672400
# 4684700
# 4698200
# 4714100
# 4728900
# 4740000
# 4748300
# 4755600
# 4761300
# 4771800
# 4791800
# 4797200
# 4803100
# 4808400
# 4824700
# 4835000
# 4851700
# 4862100
# 4872200
# 4879000
# 4895900
# 4901400
# 4908400
# 4926000
# 4933200
# 4938300
# 4967800
# 4975800
# 4981800
# 4988900
# 4996600
# 5002000
# 5024200
# 5032500
# 5058300
# 5073900
# 5083700
# 5089000
# 5113000
# 5138500
# 5145300
# 5156900
# 5166500
# 5173800
# 5179700
# 5186200
# 5194000
# 5206300
# 5212700
# 5218100
# 5224300
# 5244100
# 5257600
# 5265000
# 5277400
# 5286000
# 5293700
# 5300900
# 5326800
# 5333700
# 5348600
# 5361500
# 5387800
# 5396500
# 5417200
# 5422600
# 5428800
# 5433900
# 5449300
# 5454900
# 5460700
# 5472100
# 5477500
# 5482900
# 5496900
# 5512700
# 5518700
# 5530000
# 5540000
# 5560700
# 5568200
# 5575600
# 5585800
# 5599100
# 5624000
# 5634800
# 5640900
# 5651800
# 5661800
# 5668400
# 5687700
# 5705400
# 5713900
# 5730200
# 5739700
# 5751300
# 5757000
# 5764000
# 5771800
# 5784700
# 5794600
# 5802000
# 5809900
# 5819500
# 5830000
# 5835400
# 5842100
# 5850600
# 5862700
# 5869100
# 5885400
# 5898800
# 5907900
# 5916500
# 5922900
# 5939300
# 5951700
# 5962100
# 5986400
# 6008000
# 6017300
# 6031000
# 6037100
# 6052100
# 6057800
# 6066100
# 6073800
# 6096000
# 6101400
# 6110100
# 6117300
# 6143900
# 6151400
# 6162400
# 6171300
# 6189100
# 6200100
# 6206700
# 6217700
# 6247700
# 6256300
# 6269700
# 6274900
# 6297200
# 6305700
# 6314100
# 6331000
# 6336700
# 6349100
# 6372300
# 6382700
# 6396600
# 6402500
# 6408900
# 6414600
# 6425900
# 6437500
# 6443700
# 6466600
# 6472400
# 6504600
# 6525300
# 6543700
# 6550000
# 6557900
# 6565500
# 6571500
# 6578200
# 6584300
# 6597900
# 6604400
# 6614400
# 6626100
# 6635600
# 6642800
# 6654900
# 6663900
# 6681000
# 6690700
# 6696000
# 6711800
# 6721200
# 6728100
# 6754500
# 6765800
# 6777900
# 6783400
# 6788900
# 6796600
# 6802800
# 6812700
# 6833800
# 6840300
# 6852400
# 6865100
# 6872800
# 6879200
# 6895700
# 6909300
# 6921800
# 6932000
# 6938900
# 6956200
# 6978000
# 6991300
# 7004800
# 7017400
# 7023600
# 7064700
# 7071000
# 7077200
# 7084200
# 7104100
# 7115100
# 7127400
# 7142100
# 7152700
# 7160000
# 7172300
# 7181800
# 7194300
# 7209700
# 7220600
# 7230900
# 7238100
# 7244800
# 7251500
# 7260200
# 7296300
# 7302400
# 7315500
# 7322200
# 7337500
# 7348800
# 7363000
# 7372800
# 7389800
# 7399800
# 7406400
# 7420000
# 7428400
# 7451600
# 7462500
# 7473700
# 7481600
# 7488200
# 7494700
# 7500700
# 7516000
# 7533500
# 7541500
# 7547200
# 7553400
# 7559500
# 7565700
# 7574000
# 7589000
# 7594900
# 7601500
# 7616500
# 7629000
# 7641800
# 7648700
# 7657700
# 7667300
# 7674300
# 7683300
# 7689000
# 7702500
# 7714900
# 7724000
# 7747700
# 7756100
# 7782900
# 7813800
# 7819800
# 7830200
# 7855600
# 7898200
# 7909200
# 7915700
# 7934000
# 7940800
# 7967800
# 7974700
# 7985500
# 8014700
# 8024800
# 8037000
# 8047200
# 8055500
# 8064200
# 8077100
# 8083600
# 8090700
# 8102000
# 8109100
# 8122000
# 8130700
# 8139200
# 8153100
# 8161500
# 8170700
# 8176900
# 8197000
# 8206300
# 8213600
# 8229400
# 8242500
# 8263000
# 8274100
# 8282700
# 8295000
# 8304900
# 8321300
# 8347000
# 8354800
# 8369700
# 8386500
# 8396700
# 8413600
# 8419800
# 8458700
# 8479200
# 8485100
# 8498500
# 8506100
# 8518900
# 8525800
# 8534800
# 8553800
# 8560000
# 8570000
# 8591600
# 8614400
# 8621200
# 8638600
# 8659000
# 8667800
# 8680900
# 8692300
# 8703200
# 8724600
# 8733500
# 8744900
# 8752000
# 8761000
# 8766800
# 8772900
# 8782700
# 8796700
# 8807600
# 8816600
# 8825100
# 8833600
# 8841200
# 8854900
# 8862300
# 8868800
# 8893700
# 8918500
# 8925700
# 8938000
# 8945400
# 8959200
# 8965100
# 8972000
# 8998300
# 9005700
# 9019200
# 9049300
# 9057400
# 9068600
# 9083000
# 9103800
# 9110200
# 9117800
# 9134800
# 9161100
# 9177800
# 9191400
# 9199900
# 9208300
# 9215000
# 9228400
# 9236800
# 9250600
# 9258500
# 9266900
# 9276000
# 9287000
# 9293800
# 9308400
# 9339600
# 9349800
# 9364400
# 9371500
# 9387500
# 9397800
# 9404100
# 9410200
# 9421900
# 9430800
# 9438500
# 9451700
# 9463500
# 9477900
# 9493300
# 9512200
# 9522700
# 9534300
# 9563900
# 9579800
# 9588200
# 9599000
# 9613700
# 9619900
# 9628900
# 9645200
# 9666100
# 9685800
# 9693100
# 9711000
# 9716900
# 9729900
# 9737100
# 9742900
# 9756600
# 9768100
# 9780100
# 9792700
# 9807800
# 9823200
# 9842800
# 9849000
# 9861200
# 9874000
# 9898100
# 9909100
# 9923800
# 9935300
# 9945200
# 9956200
# 9978400
# 9987000
# 9999300

# %% [markdown]
# If you open the file with a text editor, you'll see that this is also the way the editor will parse the file. That is, the newline characters (`\n`) get parsed as a carriage return (think type-writer...).
#
# The content of this file is a header segment (the lines starting with `#`) and a data segment. The header information will be important because we want to know what intensity of stimulus was used for this cell (that's the line `# intensity (dB): 76.4286`)
#
#
# The data in integers, below the header information are spike times during one trial, given in micro-seconds. Just by looking at these numbers, can you infer what the sampling rate was?

# %% [markdown]
# How would we go about converting the string we got into numbers we can use to analyze (preferably packaged in a `numpy array`)? Maybe we can use the `file`'s `readline` method and parse the data line-by-line?

# %%
# Use readline
f_st_1.readline()
# Out:
# ''

# %% [markdown]
# What happened there?

# %% [markdown]
# It turns out that the `file` object has a state: it keeps track of the point to which it has most recently read. Since we previously used `read`, which reads in the entire file, we are at the end of it now. Let's use `seek` to get back to the beginning of the file

# %%
# To reset the state of the file to point to the beginning of the file, use `seek`: 
f_st_1.seek(0)

# %% [markdown]
# Note: take a look at the docstring for `seek`. It takes as input a byte count from a given point in the file. 0 is the very beginning of the file. If we use `tell` to assess that we can see that:

# %%
# To assess where you are, use `tell`
f_st_1.tell()
# Out:
# 0

# %% [markdown]
# Now let's use `readline` again:

# %%
# When we next use readline, we get the first line of the file:
line = f_st_1.readline()
line
# Out:
# '# repro call number: 0\n'

# %% [markdown]
# That gives us the very first line in the file. Where are we now?

# %% [markdown]
# Where did that number come from? Any guesses?

# %% [markdown]
# One reasonable guess at this point would be that there is a one-to-one mapping between bytes into the file and characters in the string. This may become a bit more tricky if you are trying to read other formats of data, but for now, let's just leave it at that.

# %% [markdown]
# ### Exercise: make an `array` reading the file with `readline`.
#
# ### Important : we don't want to include the lines that begin with `#` in our array, only the spike times!

# %%
f_st_1.tell()
# Out:
# 23

# %%
import numpy as np

# %% [markdown]
# Data can have unexpected features, which is why it is beneficial to explore it in an interactive environment that allows probing and prodding it.

# %%
# Let's fix the problem with the above piece of code: 
f_st_1.seek(0) # Go to the beginning of the file 
lines = []
line = f_st_1.readline()

while line != '': 
    if line[0] != '#' and line != '\n':  # The more you know...
        lines.append(int(line))
    line = f_st_1.readline()
    
spike_array = np.array(lines)

# %%
spike_array.shape = (929,1)

# %%
import matplotlib.pyplot as plt

# %%
diff = np.diff(spike_array)

# %%
diff.shape = (929,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-6864e1a771ee> in <module>()
# ----> 1 diff.shape = (929,1)
#
# ValueError: total size of new array must be unchanged

# %%
print spike_array.shape , diff.shape
# Out:
# (929, 1) (929, 0)

# %%
print type(spike_array)
fig, ax=plt.subplots(1)
ax.plot(spike_array, '.')
ax.set_xlabel('number of spikes')
ax.set_ylabel('firing rate')
# Out:
# <type 'numpy.ndarray'>

# %%
fig, ax=plt.subplots(1)
ax.plot(spike_array, '.')
ax.set_xlabel('number of spikes')
ax.set_ylabel('firing rate')

# %%
ax.plot

# %%
type(ax)
# Out:
# matplotlib.axes.AxesSubplot

# %%
type(fix)

# We can display what we got:
plot(spike_array,'.')

# %% [markdown]
# What does this tell us about the firing rate of this cell? What do you think the duration of the trial was?

# %% [markdown]
# It turns out that there is another option that will do this more elegantly for us. Enter `readlines`:

# %%
# Use readlines to get all the lines in the file
f_st_1.seek(0)
lines = f_st_1.readlines()

# %%
# Take a look at it:
lines

# %% [markdown]
# The `readlines` method returns a list of strings. This is something that we can iterate over.

# %%
# Revise our file-reading routine:

f_st_1.seek(0) # Go to the beginning of the file 
lines = []

for line in f_st_1.readlines():
    if line[0] != '#' and line != '\n':
        lines.append(int(line))
    line = f_st_1.readline()
    
spike_array = np.array(lines)

# %% [markdown]
# ### A short aside about list comprehensions.
#
# [List comprehensions](http://docs.python.org/2/tutorial/datastructures.html#list-comprehensions) are one of the most elegant constructs in Python (consistently voted for "favorite feature of the language" by nerds everywhere). It can be a bit confusing on first blush, but once you start using them, it can become addictive.
#
# Here's how it works: you can construct a list by surrounding an iteration with square brackets. For example, this:

# %%
a = [] 
for x in range(10):
    a.append(x**2)
print a

# %% [markdown]
# is equivalent to this:

# %%
a = [x**2 for x in range(10)]
print a

# %% [markdown]
# You can also embed a logical statement in there for selection:

# %%
# Only square the non-zero even elements:
a = [x**2 for x in range(10) if x>0 and np.mod(x,2)==0]
print a

# %% [markdown]
# Back to our readlines function from above. How would you generate the spike-time array using a list comprehension?

# %%
# Here's what the file-reading routine looks like with a list comprehension
f_st_1.seek(0)
# The following is equivalent to the above loop + call to array
spike_array = np.array([int(l) for l in f_st_1.readlines() if l[0] != '#' and l != '\n'])

# %%
# As a sanity check, plot the array you got. Does it look the same as before?
plot(spike_array)

# %% [markdown]
# Before moving on, it is generally a good idea to close open files when you are done with them:

# %%
# Calling the `close` method closes the file cleanly:
f_st_1.close()

# %% [markdown]
# Knowing how to deal with text files is quite useful.
#
# Having now learned that, let me now reveal to you that as I hinted before, `numpy` actually has a function that will do all of this for us:

# %%
# Use `loadtxt` instead of what you did above:
spike_array = np.loadtxt('grasshopper_spike_times1.txt')

# %% [markdown]
# It even knows not to read the comment lines and to ignore empty lines.
#
# Consider that when you generate your own data files.

# %%
# Plot it as a sanity check
plot(spike_array)

# %% [markdown]
# Actually `loadtxt` is quite a bit more sophisticated than our little loop:

# %%
# We can look at the file, just to convince ourselves that it's doing much more than what we did:
np.loadtxt??

# %%
a='# item1: 3'

# %%
a[2:a.find(':')]
# Out:
# 'item'

# %%
a[a.find('#')+2:]
# Out:
# 'item1: 3'

# %%
a.find?

# %% [markdown]
# ### Exercise : write a function that will take as input the file-name and returns:
#
# ### 1. A numpy array with the spike times
# ### 2. A dictionary with the header information
#
# It should do something like:
#
#     spikes, header = get_data(fname)
#
# Where `spikes` is the array and `header` is the dict with header information

# %%
def get_header(fname):
    file_object = open(fname)
    header = {}
    for line in file_object.readlines():
        colon = line.find(':')
        if colon is -1:
            return header
        else:
            header[line[2:colon]] = line[colon+2:]

# %%
fname = 'grasshopper_spike_times1.txt'

# %%
get_header(fname)
# Out:
# {'carrier freq (kHz)': '2.5\n',
#  'cut-off frequency (Hz)': '200\n',
#  'desired firing rate (Hz)': '100\n',
#  'duration (msec)': '1000\n',
#  'intensity (dB)': '76.4286\n',
#  'length of ramp (usec)': '1000\n',
#  'mode': '3\n',
#  'pause between stimuli (msec)': '700\n',
#  'repetition number': '0\n',
#  'repro call number': '0\n',
#  'signal': '1\n',
#  'standard deviation (dB)': '6\n',
#  'stimulus file': '/extra/setup/oel/stimuli/receptorInfo/gauss_st6_co200.dat\n',
#  'stimulus length (msec)': '1000\n'}

# %%
def get_data(fname):
    return [np.loadtxt(fname), get_header(fname)]

# %%
get_data(fname)
# Out:
# [array([  6.70000000e+03,   9.90000000e+03,   1.39000000e+04,
#          2.01000000e+04,   2.50000000e+04,   2.84000000e+04,
#          3.70000000e+04,   4.06000000e+04,   4.63000000e+04,
#          5.05000000e+04,   5.99000000e+04,   6.88000000e+04,
#          7.52000000e+04,   8.06000000e+04,   8.43000000e+04,
#          8.80000000e+04,   9.32000000e+04,   1.04800000e+05,
#          1.18400000e+05,   1.28500000e+05,   1.35800000e+05,
#          1.45600000e+05,   1.48800000e+05,   1.57100000e+05,
#          1.70900000e+05,   1.82800000e+05,   1.98600000e+05,
#          2.09500000e+05,   2.14000000e+05,   2.17900000e+05,
#          2.21100000e+05,   2.28700000e+05,   2.38500000e+05,
#          2.44500000e+05,   2.57600000e+05,   2.61800000e+05,
#          2.69100000e+05,   2.78200000e+05,   2.85400000e+05,
#          2.99100000e+05,   3.02800000e+05,   3.06100000e+05,
#          3.33900000e+05,   3.43800000e+05,   3.52300000e+05,
#          3.55900000e+05,   3.62200000e+05,   3.68300000e+05,
#          3.71700000e+05,   3.86900000e+05,   3.97400000e+05,
#          4.04600000e+05,   4.13300000e+05,   4.18900000e+05,
#          4.27400000e+05,   4.30800000e+05,   4.35900000e+05,
#          4.41400000e+05,   4.56100000e+05,   4.61600000e+05,
#          4.65200000e+05,   4.69300000e+05,   4.74400000e+05,
#          4.80700000e+05,   4.84600000e+05,   4.88700000e+05,
#          4.96800000e+05,   5.03800000e+05,   5.14500000e+05,
#          5.30100000e+05,   5.36700000e+05,   5.44800000e+05,
#          5.49400000e+05,   5.54600000e+05,   5.64000000e+05,
#          5.84300000e+05,   5.91200000e+05,   5.97500000e+05,
#          6.07500000e+05,   6.11800000e+05,   6.15500000e+05,
#          6.19100000e+05,   6.27200000e+05,   6.31500000e+05,
#          6.35200000e+05,   6.58900000e+05,   6.69700000e+05,
#          6.74300000e+05,   6.78300000e+05,   6.83300000e+05,
#          6.90000000e+05,   6.93700000e+05,   7.04900000e+05,
#          7.16000000e+05,   7.19700000e+05,   7.24600000e+05,
#          7.29800000e+05,   7.40800000e+05,   7.49300000e+05,
#          7.59500000e+05,   7.70900000e+05,   7.90800000e+05,
#          7.94400000e+05,   8.01600000e+05,   8.13100000e+05,
#          8.17100000e+05,   8.35000000e+05,   8.45000000e+05,
#          8.49900000e+05,   8.57700000e+05,   8.65200000e+05,
#          8.68900000e+05,   8.75000000e+05,   8.83900000e+05,
#          8.93600000e+05,   9.04600000e+05,   9.19100000e+05,
#          9.24900000e+05,   9.29900000e+05,   9.36400000e+05,
#          9.40200000e+05,   9.57700000e+05,   9.61700000e+05,
#          9.67900000e+05,   9.73300000e+05,   9.79400000e+05,
#          9.88200000e+05,   1.00280000e+06,   1.00940000e+06,
#          1.02400000e+06,   1.03010000e+06,   1.04760000e+06,
#          1.05620000e+06,   1.06720000e+06,   1.07640000e+06,
#          1.08110000e+06,   1.08790000e+06,   1.09620000e+06,
#          1.11430000e+06,   1.12600000e+06,   1.13530000e+06,
#          1.14310000e+06,   1.15260000e+06,   1.15750000e+06,
#          1.16600000e+06,   1.17590000e+06,   1.18590000e+06,
#          1.19180000e+06,   1.19940000e+06,   1.21200000e+06,
#          1.22370000e+06,   1.23510000e+06,   1.24060000e+06,
#          1.24530000e+06,   1.25160000e+06,   1.25660000e+06,
#          1.26750000e+06,   1.27420000e+06,   1.28660000e+06,
#          1.29130000e+06,   1.29650000e+06,   1.30560000e+06,
#          1.31250000e+06,   1.31690000e+06,   1.33850000e+06,
#          1.34520000e+06,   1.36410000e+06,   1.37850000e+06,
#          1.39070000e+06,   1.39470000e+06,   1.40030000e+06,
#          1.40560000e+06,   1.41250000e+06,   1.42020000e+06,
#          1.43060000e+06,   1.44700000e+06,   1.45190000e+06,
#          1.47820000e+06,   1.48810000e+06,   1.49990000e+06,
#          1.51190000e+06,   1.51740000e+06,   1.53200000e+06,
#          1.54280000e+06,   1.55000000e+06,   1.55570000e+06,
#          1.58060000e+06,   1.58770000e+06,   1.59360000e+06,
#          1.60940000e+06,   1.61680000e+06,   1.62770000e+06,
#          1.63500000e+06,   1.63990000e+06,   1.65670000e+06,
#          1.66190000e+06,   1.67170000e+06,   1.67890000e+06,
#          1.68360000e+06,   1.69290000e+06,   1.70550000e+06,
#          1.72160000e+06,   1.72780000e+06,   1.73660000e+06,
#          1.74330000e+06,   1.75670000e+06,   1.76120000e+06,
#          1.78070000e+06,   1.78710000e+06,   1.81000000e+06,
#          1.81580000e+06,   1.82720000e+06,   1.83390000e+06,
#          1.84140000e+06,   1.85620000e+06,   1.86280000e+06,
#          1.86820000e+06,   1.87770000e+06,   1.89080000e+06,
#          1.89960000e+06,   1.91270000e+06,   1.93210000e+06,
#          1.95040000e+06,   1.96110000e+06,   1.96770000e+06,
#          1.97220000e+06,   1.98840000e+06,   1.99780000e+06,
#          2.00240000e+06,   2.01680000e+06,   2.03440000e+06,
#          2.04830000e+06,   2.05690000e+06,   2.06980000e+06,
#          2.07880000e+06,   2.08420000e+06,   2.09960000e+06,
#          2.11050000e+06,   2.11560000e+06,   2.13540000e+06,
#          2.16210000e+06,   2.17130000e+06,   2.18140000e+06,
#          2.19290000e+06,   2.20960000e+06,   2.21570000e+06,
#          2.23040000e+06,   2.23760000e+06,   2.24370000e+06,
#          2.25700000e+06,   2.26180000e+06,   2.26720000e+06,
#          2.27360000e+06,   2.27860000e+06,   2.29070000e+06,
#          2.29640000e+06,   2.30310000e+06,   2.31540000e+06,
#          2.32030000e+06,   2.32800000e+06,   2.34190000e+06,
#          2.34750000e+06,   2.35730000e+06,   2.37190000e+06,
#          2.37740000e+06,   2.38320000e+06,   2.39380000e+06,
#          2.39880000e+06,   2.41310000e+06,   2.42730000e+06,
#          2.43470000e+06,   2.44210000e+06,   2.45390000e+06,
#          2.46010000e+06,   2.47790000e+06,   2.49320000e+06,
#          2.49840000e+06,   2.51190000e+06,   2.51910000e+06,
#          2.52750000e+06,   2.54490000e+06,   2.56370000e+06,
#          2.57320000e+06,   2.57980000e+06,   2.58910000e+06,
#          2.59440000e+06,   2.60040000e+06,   2.60940000e+06,
#          2.61450000e+06,   2.62590000e+06,   2.63940000e+06,
#          2.65000000e+06,   2.66060000e+06,   2.67480000e+06,
#          2.69080000e+06,   2.69810000e+06,   2.70290000e+06,
#          2.71510000e+06,   2.72580000e+06,   2.73990000e+06,
#          2.75120000e+06,   2.75730000e+06,   2.76900000e+06,
#          2.77630000e+06,   2.79090000e+06,   2.79760000e+06,
#          2.80950000e+06,   2.81640000e+06,   2.82370000e+06,
#          2.83310000e+06,   2.83860000e+06,   2.84350000e+06,
#          2.84980000e+06,   2.86040000e+06,   2.86670000e+06,
#          2.87920000e+06,   2.88750000e+06,   2.89300000e+06,
#          2.89770000e+06,   2.90490000e+06,   2.91500000e+06,
#          2.92580000e+06,   2.93180000e+06,   2.93860000e+06,
#          2.94800000e+06,   2.95740000e+06,   2.96400000e+06,
#          2.96960000e+06,   2.98350000e+06,   2.99280000e+06,
#          2.99930000e+06,   3.01480000e+06,   3.02670000e+06,
#          3.03970000e+06,   3.04590000e+06,   3.05640000e+06,
#          3.06450000e+06,   3.07470000e+06,   3.09060000e+06,
#          3.10250000e+06,   3.11330000e+06,   3.12250000e+06,
#          3.13550000e+06,   3.14570000e+06,   3.15510000e+06,
#          3.16430000e+06,   3.18840000e+06,   3.19630000e+06,
#          3.20120000e+06,   3.21330000e+06,   3.22980000e+06,
#          3.23570000e+06,   3.24780000e+06,   3.25480000e+06,
#          3.26190000e+06,   3.27200000e+06,   3.27950000e+06,
#          3.28700000e+06,   3.29710000e+06,   3.30490000e+06,
#          3.32220000e+06,   3.33960000e+06,   3.35070000e+06,
#          3.35760000e+06,   3.36870000e+06,   3.37630000e+06,
#          3.38520000e+06,   3.39180000e+06,   3.39880000e+06,
#          3.42100000e+06,   3.43180000e+06,   3.45030000e+06,
#          3.45630000e+06,   3.47080000e+06,   3.47680000e+06,
#          3.48220000e+06,   3.49410000e+06,   3.50720000e+06,
#          3.51700000e+06,   3.53820000e+06,   3.54610000e+06,
#          3.55430000e+06,   3.57160000e+06,   3.57970000e+06,
#          3.58870000e+06,   3.59710000e+06,   3.61060000e+06,
#          3.62120000e+06,   3.63880000e+06,   3.64410000e+06,
#          3.65060000e+06,   3.66150000e+06,   3.67300000e+06,
#          3.68370000e+06,   3.71360000e+06,   3.72490000e+06,
#          3.74590000e+06,   3.75080000e+06,   3.75620000e+06,
#          3.76300000e+06,   3.76850000e+06,   3.78350000e+06,
#          3.79500000e+06,   3.80360000e+06,   3.80890000e+06,
#          3.82010000e+06,   3.83610000e+06,   3.84490000e+06,
#          3.85600000e+06,   3.87240000e+06,   3.87860000e+06,
#          3.88770000e+06,   3.90050000e+06,   3.90640000e+06,
#          3.91720000e+06,   3.92240000e+06,   3.93220000e+06,
#          3.94720000e+06,   3.95650000e+06,   3.97440000e+06,
#          3.99310000e+06,   4.00220000e+06,   4.00700000e+06,
#          4.01260000e+06,   4.01950000e+06,   4.04430000e+06,
#          4.05270000e+06,   4.06470000e+06,   4.07330000e+06,
#          4.08490000e+06,   4.09830000e+06,   4.10490000e+06,
#          4.11760000e+06,   4.12270000e+06,   4.13260000e+06,
#          4.16240000e+06,   4.17210000e+06,   4.17710000e+06,
#          4.18670000e+06,   4.19200000e+06,   4.19900000e+06,
#          4.20430000e+06,   4.21820000e+06,   4.22520000e+06,
#          4.23460000e+06,   4.24040000e+06,   4.24730000e+06,
#          4.26390000e+06,   4.28210000e+06,   4.28980000e+06,
#          4.29830000e+06,   4.31530000e+06,   4.32430000e+06,
#          4.33290000e+06,   4.34930000e+06,   4.36930000e+06,
#          4.37790000e+06,   4.39360000e+06,   4.40170000e+06,
#          4.40770000e+06,   4.42640000e+06,   4.43210000e+06,
#          4.44050000e+06,   4.44730000e+06,   4.45460000e+06,
#          4.46990000e+06,   4.47690000e+06,   4.48560000e+06,
#          4.49150000e+06,   4.49870000e+06,   4.50800000e+06,
#          4.52450000e+06,   4.53590000e+06,   4.55830000e+06,
#          4.56510000e+06,   4.57590000e+06,   4.58710000e+06,
#          4.59340000e+06,   4.60080000e+06,   4.61180000e+06,
#          4.64030000e+06,   4.65160000e+06,   4.66360000e+06,
#          4.67240000e+06,   4.68470000e+06,   4.69820000e+06,
#          4.71410000e+06,   4.72890000e+06,   4.74000000e+06,
#          4.74830000e+06,   4.75560000e+06,   4.76130000e+06,
#          4.77180000e+06,   4.79180000e+06,   4.79720000e+06,
#          4.80310000e+06,   4.80840000e+06,   4.82470000e+06,
#          4.83500000e+06,   4.85170000e+06,   4.86210000e+06,
#          4.87220000e+06,   4.87900000e+06,   4.89590000e+06,
#          4.90140000e+06,   4.90840000e+06,   4.92600000e+06,
#          4.93320000e+06,   4.93830000e+06,   4.96780000e+06,
#          4.97580000e+06,   4.98180000e+06,   4.98890000e+06,
#          4.99660000e+06,   5.00200000e+06,   5.02420000e+06,
#          5.03250000e+06,   5.05830000e+06,   5.07390000e+06,
#          5.08370000e+06,   5.08900000e+06,   5.11300000e+06,
#          5.13850000e+06,   5.14530000e+06,   5.15690000e+06,
#          5.16650000e+06,   5.17380000e+06,   5.17970000e+06,
#          5.18620000e+06,   5.19400000e+06,   5.20630000e+06,
#          5.21270000e+06,   5.21810000e+06,   5.22430000e+06,
#          5.24410000e+06,   5.25760000e+06,   5.26500000e+06,
#          5.27740000e+06,   5.28600000e+06,   5.29370000e+06,
#          5.30090000e+06,   5.32680000e+06,   5.33370000e+06,
#          5.34860000e+06,   5.36150000e+06,   5.38780000e+06,
#          5.39650000e+06,   5.41720000e+06,   5.42260000e+06,
#          5.42880000e+06,   5.43390000e+06,   5.44930000e+06,
#          5.45490000e+06,   5.46070000e+06,   5.47210000e+06,
#          5.47750000e+06,   5.48290000e+06,   5.49690000e+06,
#          5.51270000e+06,   5.51870000e+06,   5.53000000e+06,
#          5.54000000e+06,   5.56070000e+06,   5.56820000e+06,
#          5.57560000e+06,   5.58580000e+06,   5.59910000e+06,
#          5.62400000e+06,   5.63480000e+06,   5.64090000e+06,
#          5.65180000e+06,   5.66180000e+06,   5.66840000e+06,
#          5.68770000e+06,   5.70540000e+06,   5.71390000e+06,
#          5.73020000e+06,   5.73970000e+06,   5.75130000e+06,
#          5.75700000e+06,   5.76400000e+06,   5.77180000e+06,
#          5.78470000e+06,   5.79460000e+06,   5.80200000e+06,
#          5.80990000e+06,   5.81950000e+06,   5.83000000e+06,
#          5.83540000e+06,   5.84210000e+06,   5.85060000e+06,
#          5.86270000e+06,   5.86910000e+06,   5.88540000e+06,
#          5.89880000e+06,   5.90790000e+06,   5.91650000e+06,
#          5.92290000e+06,   5.93930000e+06,   5.95170000e+06,
#          5.96210000e+06,   5.98640000e+06,   6.00800000e+06,
#          6.01730000e+06,   6.03100000e+06,   6.03710000e+06,
#          6.05210000e+06,   6.05780000e+06,   6.06610000e+06,
#          6.07380000e+06,   6.09600000e+06,   6.10140000e+06,
#          6.11010000e+06,   6.11730000e+06,   6.14390000e+06,
#          6.15140000e+06,   6.16240000e+06,   6.17130000e+06,
#          6.18910000e+06,   6.20010000e+06,   6.20670000e+06,
#          6.21770000e+06,   6.24770000e+06,   6.25630000e+06,
#          6.26970000e+06,   6.27490000e+06,   6.29720000e+06,
#          6.30570000e+06,   6.31410000e+06,   6.33100000e+06,
#          6.33670000e+06,   6.34910000e+06,   6.37230000e+06,
#          6.38270000e+06,   6.39660000e+06,   6.40250000e+06,
#          6.40890000e+06,   6.41460000e+06,   6.42590000e+06,
#          6.43750000e+06,   6.44370000e+06,   6.46660000e+06,
#          6.47240000e+06,   6.50460000e+06,   6.52530000e+06,
#          6.54370000e+06,   6.55000000e+06,   6.55790000e+06,
#          6.56550000e+06,   6.57150000e+06,   6.57820000e+06,
#          6.58430000e+06,   6.59790000e+06,   6.60440000e+06,
#          6.61440000e+06,   6.62610000e+06,   6.63560000e+06,
#          6.64280000e+06,   6.65490000e+06,   6.66390000e+06,
#          6.68100000e+06,   6.69070000e+06,   6.69600000e+06,
#          6.71180000e+06,   6.72120000e+06,   6.72810000e+06,
#          6.75450000e+06,   6.76580000e+06,   6.77790000e+06,
#          6.78340000e+06,   6.78890000e+06,   6.79660000e+06,
#          6.80280000e+06,   6.81270000e+06,   6.83380000e+06,
#          6.84030000e+06,   6.85240000e+06,   6.86510000e+06,
#          6.87280000e+06,   6.87920000e+06,   6.89570000e+06,
#          6.90930000e+06,   6.92180000e+06,   6.93200000e+06,
#          6.93890000e+06,   6.95620000e+06,   6.97800000e+06,
#          6.99130000e+06,   7.00480000e+06,   7.01740000e+06,
#          7.02360000e+06,   7.06470000e+06,   7.07100000e+06,
#          7.07720000e+06,   7.08420000e+06,   7.10410000e+06,
#          7.11510000e+06,   7.12740000e+06,   7.14210000e+06,
#          7.15270000e+06,   7.16000000e+06,   7.17230000e+06,
#          7.18180000e+06,   7.19430000e+06,   7.20970000e+06,
#          7.22060000e+06,   7.23090000e+06,   7.23810000e+06,
#          7.24480000e+06,   7.25150000e+06,   7.26020000e+06,
#          7.29630000e+06,   7.30240000e+06,   7.31550000e+06,
#          7.32220000e+06,   7.33750000e+06,   7.34880000e+06,
#          7.36300000e+06,   7.37280000e+06,   7.38980000e+06,
#          7.39980000e+06,   7.40640000e+06,   7.42000000e+06,
#          7.42840000e+06,   7.45160000e+06,   7.46250000e+06,
#          7.47370000e+06,   7.48160000e+06,   7.48820000e+06,
#          7.49470000e+06,   7.50070000e+06,   7.51600000e+06,
#          7.53350000e+06,   7.54150000e+06,   7.54720000e+06,
#          7.55340000e+06,   7.55950000e+06,   7.56570000e+06,
#          7.57400000e+06,   7.58900000e+06,   7.59490000e+06,
#          7.60150000e+06,   7.61650000e+06,   7.62900000e+06,
#          7.64180000e+06,   7.64870000e+06,   7.65770000e+06,
#          7.66730000e+06,   7.67430000e+06,   7.68330000e+06,
#          7.68900000e+06,   7.70250000e+06,   7.71490000e+06,
#          7.72400000e+06,   7.74770000e+06,   7.75610000e+06,
#          7.78290000e+06,   7.81380000e+06,   7.81980000e+06,
#          7.83020000e+06,   7.85560000e+06,   7.89820000e+06,
#          7.90920000e+06,   7.91570000e+06,   7.93400000e+06,
#          7.94080000e+06,   7.96780000e+06,   7.97470000e+06,
#          7.98550000e+06,   8.01470000e+06,   8.02480000e+06,
#          8.03700000e+06,   8.04720000e+06,   8.05550000e+06,
#          8.06420000e+06,   8.07710000e+06,   8.08360000e+06,
#          8.09070000e+06,   8.10200000e+06,   8.10910000e+06,
#          8.12200000e+06,   8.13070000e+06,   8.13920000e+06,
#          8.15310000e+06,   8.16150000e+06,   8.17070000e+06,
#          8.17690000e+06,   8.19700000e+06,   8.20630000e+06,
#          8.21360000e+06,   8.22940000e+06,   8.24250000e+06,
#          8.26300000e+06,   8.27410000e+06,   8.28270000e+06,
#          8.29500000e+06,   8.30490000e+06,   8.32130000e+06,
#          8.34700000e+06,   8.35480000e+06,   8.36970000e+06,
#          8.38650000e+06,   8.39670000e+06,   8.41360000e+06,
#          8.41980000e+06,   8.45870000e+06,   8.47920000e+06,
#          8.48510000e+06,   8.49850000e+06,   8.50610000e+06,
#          8.51890000e+06,   8.52580000e+06,   8.53480000e+06,
#          8.55380000e+06,   8.56000000e+06,   8.57000000e+06,
#          8.59160000e+06,   8.61440000e+06,   8.62120000e+06,
#          8.63860000e+06,   8.65900000e+06,   8.66780000e+06,
#          8.68090000e+06,   8.69230000e+06,   8.70320000e+06,
#          8.72460000e+06,   8.73350000e+06,   8.74490000e+06,
#          8.75200000e+06,   8.76100000e+06,   8.76680000e+06,
#          8.77290000e+06,   8.78270000e+06,   8.79670000e+06,
#          8.80760000e+06,   8.81660000e+06,   8.82510000e+06,
#          8.83360000e+06,   8.84120000e+06,   8.85490000e+06,
#          8.86230000e+06,   8.86880000e+06,   8.89370000e+06,
#          8.91850000e+06,   8.92570000e+06,   8.93800000e+06,
#          8.94540000e+06,   8.95920000e+06,   8.96510000e+06,
#          8.97200000e+06,   8.99830000e+06,   9.00570000e+06,
#          9.01920000e+06,   9.04930000e+06,   9.05740000e+06,
#          9.06860000e+06,   9.08300000e+06,   9.10380000e+06,
#          9.11020000e+06,   9.11780000e+06,   9.13480000e+06,
#          9.16110000e+06,   9.17780000e+06,   9.19140000e+06,
#          9.19990000e+06,   9.20830000e+06,   9.21500000e+06,
#          9.22840000e+06,   9.23680000e+06,   9.25060000e+06,
#          9.25850000e+06,   9.26690000e+06,   9.27600000e+06,
#          9.28700000e+06,   9.29380000e+06,   9.30840000e+06,
#          9.33960000e+06,   9.34980000e+06,   9.36440000e+06,
#          9.37150000e+06,   9.38750000e+06,   9.39780000e+06,
#          9.40410000e+06,   9.41020000e+06,   9.42190000e+06,
#          9.43080000e+06,   9.43850000e+06,   9.45170000e+06,
#          9.46350000e+06,   9.47790000e+06,   9.49330000e+06,
#          9.51220000e+06,   9.52270000e+06,   9.53430000e+06,
#          9.56390000e+06,   9.57980000e+06,   9.58820000e+06,
#          9.59900000e+06,   9.61370000e+06,   9.61990000e+06,
#          9.62890000e+06,   9.64520000e+06,   9.66610000e+06,
#          9.68580000e+06,   9.69310000e+06,   9.71100000e+06,
#          9.71690000e+06,   9.72990000e+06,   9.73710000e+06,
#          9.74290000e+06,   9.75660000e+06,   9.76810000e+06,
#          9.78010000e+06,   9.79270000e+06,   9.80780000e+06,
#          9.82320000e+06,   9.84280000e+06,   9.84900000e+06,
#          9.86120000e+06,   9.87400000e+06,   9.89810000e+06,
#          9.90910000e+06,   9.92380000e+06,   9.93530000e+06,
#          9.94520000e+06,   9.95620000e+06,   9.97840000e+06,
#          9.98700000e+06,   9.99930000e+06]),
#  {'carrier freq (kHz)': '2.5\n',
#   'cut-off frequency (Hz)': '200\n',
#   'desired firing rate (Hz)': '100\n',
#   'duration (msec)': '1000\n',
#   'intensity (dB)': '76.4286\n',
#   'length of ramp (usec)': '1000\n',
#   'mode': '3\n',
#   'pause between stimuli (msec)': '700\n',
#   'repetition number': '0\n',
#   'repro call number': '0\n',
#   'signal': '1\n',
#   'standard deviation (dB)': '6\n',
#   'stimulus file': '/extra/setup/oel/stimuli/receptorInfo/gauss_st6_co200.dat\n',
#   'stimulus length (msec)': '1000\n'}]

# %%
# Define a function that does these things:
def get_data(fname): 
    """ 
    Read spike time data and header information from file

    Parameters 
    ----------
    fname : str
        Path to the file 

    Returns
    -------
    spikes : 1-d array
        Contains the spike times in the order they were 
        recorded in the file
    
    header : dict
        Header information from the data file
    """
    f = open(fname, 'r')
    header = {}
    l = f.readline()
    while l.startswith('#'):  # Same as l[0]=='#' 
        line_parts = l.split(':')
        # We split the key again, so that we don't get the '#'
        header[line_parts[0].split('# ')[-1]] = line_parts[1]
        l = f.readline()

    f.close()
    spikes = np.loadtxt(fname)
    
    return spikes, header

# %%
spikes, header = get_data('grasshopper_spike_times1.txt')

# %%
header

# %% [markdown]
# Note that the header value fields are all strings now, but that doesn't make sense for most of these. However, they can't all be cast to floating point numbers, so we'll need to do something clever:

# %%
def get_data(fname): 
    """ 
    Read spike time data and header information from file

    Parameters 
    ----------
    fname : str
        Path to the file 

    Returns
    -------
    spikes : 1-d array
        Contains the spike times in the order they were 
        recorded in the file
    
    header : dict
        Header information from the data file
    """
    f = open(fname, 'r')
    header = {}
    l = f.readline()
    while l.startswith('#'):  # Same as l[0]=='#' 
        line_parts = l.split(':')
        # We split the key again, so that we don't get the '#'
        try:
            header[line_parts[0].split('# ')[-1]] = float(line_parts[1])
        except:
            header[line_parts[0].split('# ')[-1]] = line_parts[1]
        l = f.readline()
    
    spikes = np.loadtxt(fname)
    f.close()
    return spikes, header

# %%
spikes, header = get_data('grasshopper_spike_times1.txt')

# %%
header

# %% [markdown]
# ## Let's recap what we've seen so far:
#
# - We've acquainted ourselves with the `file` class instance.
# - We took a little interlude to appreciate the beauty of list comprehensions
# - We've learned how to use `np.loadtxt`
# - We wrote a script to read spike-time data and header information

# %% [markdown]
# ### Next, let's consider the stimulus files
#
# Let's take a look:

# %%
f = open('grasshopper_stimulus1.txt')
print f.read()

# %% [markdown]
# This file contains two columns delimited by two spaces. The first designates a time-bin during the experiment (at 20 kHz) and the other is the voltage passed to the experimental equipment to produce a sound pressure wave from the speakers.
#
# From reading the documentation on the CRCNS wesbite, you can learn that the transformation between voltage and dB SPL is rather straight-forward:

# %%
def volt2dB(volt, max_dB):
    """ 
    Convert from voltage to dB SPL

    Parameters 
    ----------
    volt : 1d array
        The stimulus in volts 
    
    max_dB : int or float 
        The maximal dB value presented in the experiment
    
    Notes
    -----
    `max_dB` can be gleaned from the header information, see `get_data`
    """
    stim = 20  * (np.log10(volt / 2.0e-5))
    return max_dB - stim.max() + stim

# %% [markdown]
# To read the file, we will use a function called csv2rec.

# %%
mlab.csv2rec?

# %% [markdown]
# This function takes a file name as input and returns a so-called `recarray`:

# %%
rec_arr = mlab.csv2rec('grasshopper_stimulus1.txt', delimiter=' ', names = ['time', 'volt'])

# %% [markdown]
# To understand the difference between a `recarray` and a standard `numpy` `array`, let's look at some of the salient differences between them:

# %%
a = np.array([1,2,3,4,5])

# %%
print(a)
print(rec_arr)
print(a.dtype)
print(rec_arr.dtype)
print(a.shape)
print(rec_arr.shape)

# %% [markdown]
# The main differences are that:
#
# - Items in the `recarray` are all tuples
# - The dtype is a compound dtype made out of `(name, format)` tuples
# - The shape of the `recarray` indicates that it only has one dimension

# %% [markdown]
# Let's make a nice plot of the stimulus
#
# To do this, we will use the plotting API of matplotlib. This API lives in a namespace that is called 'matplotlib.pyplot'. Per convention, this namespace is imported in pylab under the name `plt`. The logic behind this is quite different from the matlab-style plotting style, but it's worth learning, because it gives you a lot of fine-grained control over your plotting and visualization in matplotlib.
#
# One of the most useful functions in this name-space is `subplots`. This gives you back handles to `Figure` and `AxisSubPlot` objects, which can do a lot of different things. The most

# %%
figure, axis = plt.subplots(1)
axis.plot(rec_arr['time'], rec_arr['volt'])
axis.set_xlabel(r'Time ($\mu$sec)')
axis.set_ylabel('Amplitude (V)')

# %%
type(figure)

# %% [markdown]
# We can use the functions we have already created to display the same stimulus in dB SPL instead:

# %%
figure, axis = plt.subplots(1)
# Convert to dB using the function we defined above: 
in_dB = volt2dB(rec_arr['volt'], header['intensity (dB)'])
# Then display:
axis.plot(rec_arr['time'], in_dB) 
axis.set_xlabel(r'Time ($\mu$sec)')
axis.set_ylabel('Amplitude (dB SPL)')

# %% [markdown]
# ## Analysis - computing the STA
#
# Next, we would like to compute the spike-triggered average stimulus (or STA). This characterizes the sensitivity of the cell to different stimuli.
#
# To do that, we need to average all the segments of the stimulus that preced spike times.

# %% [markdown]
# ## Let's brain-storm : how would you go about doing this?

# %% [markdown]
# There are two general strategies we could take to this:
#
# - One is to loop over our spikes and keep adding the stimuli that precede each one. This is relatively time-demanding.
#
# - The other approach is to create a binary array representing the entire trial and then using this array to index. This is typically faster, but may be relatively demanding in terms of memory
#
# Let's start with the first approach.
#
# We begin by introducing yet another piece of python magic, the [`enumerate`](http://docs.python.org/2/library/functions.html#enumerate) function. This function is used to iterate over a sequence, while also keeping track of your place in the sequence.
#
#
# For example, let's consider the following sequence:

# %%
a = [x**2 for x in range(10)]
print a

# %% [markdown]
# Now let's `enumerate` this sequence. In each iteration through the loop, we get the value of the current item in our sequence and also the index of that item. For example:

# %%
for i, n in enumerate(a):
    print i, n

# %% [markdown]
# This is equivalent to something like:

# %%
for i in range(len(a)):
    print i, a[i]

# %% [markdown]
# ### But you have to admit it's more elegant!

# %%
def sta1(spike_times, time_arr, stim_arr, num_bins=200): 
    """ 
    Calculate the STA by looping over the spikes

    Parameters
    ----------
    spike_times : 1d array
        Times of occurence of action potentials (micro-seconds)
    
    time_arr : 1d array 
        The time-bins in the stimulus presentation
    
    stim_arr : 1d array
        The stimulus values (in dB) at each time bin
    
    num_bins : int
        The number of time-bins to calculate the STA for. 

    Return 
    ------
    STA : 1d array
        The spike-triggered average stimulus 

    """
    result = []
    # We enumerate the spike times:
    for spike_idx, time in enumerate(spike_times):
        idx = np.where(time_arr == time)[0]
        result.append(stim_arr[idx-num_bins:idx])
    return np.mean(result, 0)

# %% [markdown]
# ### Can you see any salient problems with what we wrote above?

# %%
est_sta1 = sta1(spikes, rec_arr['time'], volt2dB(rec_arr['volt'], header['intensity (dB)']))

# %% [markdown]
# That's cryptic! What just happened?
#
#
# Let's fix it:

# %%
def sta1(spike_times, time_arr, stim_arr, num_bins=200): 
    """ 
    Calculate the STA by looping over the spikes

    Parameters
    ----------
    spike_times : 1d array
        Times of occurence of action potentials (micro-seconds)
    
    time_arr : 1d array 
        The time-bins in the stimulus presentation
    
    stim_arr : 1d array
        The stimulus values (in dB) at each time bin
    
    num_bins : int
        The number of time-bins to calculate the STA for. 

    Return 
    ------
    STA : 1d array
        The spike-triggered average stimulus 

    """
    result = []
    # We enumerate the spike times:
    for spike_idx, time in enumerate(spike_times):
        idx = np.where(time_arr == time)[0]
        # Only use spikes with sufficient 'history':
        if (idx - num_bins) > 0:
            result.append(stim_arr[idx-num_bins:idx])
    return np.mean(result, 0)

# %%
est_sta1 = sta1(spikes, rec_arr['time'], volt2dB(rec_arr['volt'], header['intensity (dB)']))

# %%
fig, ax = plt.subplots(1)
ax.plot(est_sta1)
ax.set_xlabel('Time (before spike)')
ax.set_ylabel('Amplitude (dB)')

# %% [markdown]
# That's pretty! The other approach is to use a big binary representation of the trial

# %%
def sta2(spike_times, time_arr, stim_arr, num_bins=200):
    """ 
    Calculate the STA by allocating a binary array

    Parameters
    ----------
    spike_times : 1d array
        Times of occurence of action potentials (micro-seconds)
    
    time_arr : 1d array 
        The time-bins in the stimulus presentation
    
    stim_arr : 1d array
        The stimulus values (in dB) at each time bin
    
    num_bins : int
        The number of time-bins to calculate the STA for. 

    Return 
    ------
    STA : 1d array
        The spike-triggered average stimulus 

    """
    raster = np.zeros(time_arr.shape)
    spike_idx = spike_times/time_arr[1] # This is a trick: the second bin is the first non-zero bin!
    # Indice arrays need  to be integers:
    spike_idx = spike_idx.astype(int)
    raster[spike_idx] = 1
    idx = np.where(raster==1)
    idx_w_len = np.array([idx[0] - count for count in range(num_bins, 0, -1)])
    return np.mean(stim_arr[idx_w_len], 1)

# %%
est_sta2 = sta2(spikes, rec_arr['time'], volt2dB(rec_arr['volt'], header['intensity (dB)']))

# %%
fig, ax = plt.subplots(1)
ax.plot(est_sta2)
ax.set_xlabel('Time (before spike)')
ax.set_ylabel('Amplitude (dB)')

# %% [markdown]
# ## Is it worth it?
#
# One way to assess this is by *profiling* them. That is, comparing the relative timing of these two functions. The `IPython` magic function `timeit` can help us measure that:

# %%
# %timeit sta2(spikes, rec_arr['time'], volt2dB(rec_arr['volt'], header['intensity (dB)']))

# %%
# %timeit sta1(spikes, rec_arr['time'], volt2dB(rec_arr['volt'], header['intensity (dB)']))

# %% [markdown]
# ## Depending on how many files you have a roughly 2 orders of magnitude speed-up can start adding up...
#
# ## Interim conclusion : if you can avoid loops, do it!

# %% [markdown]
# ## One of our implementations is clearly easier to understand. How would you go about making sure that the other one gives the right answer (except by plotting?)

# %% [markdown]
# # Let's recap again:
#
# - We've generated functions to read the data from the data-files (using `file`, `np.loadtxt` and `mlab.csv2rec`)
# - We've generated functions to calculate the STA from the data.

# %% [markdown]
# # Questions on any of this?

# %% [markdown]
# ## Exercise:
#
# - Write a set of functions that calculate both STA and STV (variance!). Try to stick to DRY : "Don't repeat yourself"
# - Using the `axis` fill_between method, plot the STA with STV error bars.

# %% [markdown]
# ## Next, let's see how we can use what we've learned here to scale up
